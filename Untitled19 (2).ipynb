# %% [markdown]
# # Workshop 2 - Object detection using web camera
# # Name : Litya M
# # Register number : 212225230152

# %%
# %pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in .\anaconda3\envs\opencv-env\Lib\site-packages (8.4.123)
# Requirement already satisfied: filelock>=3.16.1 in .\anaconda3\envs\opencv-env\Lib\site-packages (from ultralytics) (3.32.3)
# Requirement already satisfied: numpy>=1.23.0 in .\anaconda3\envs\opencv-env\Lib\site-packages (from ultralytics) (2.5.1)
# Requirement already satisfied: matplotlib>=3.3.0 in .\anaconda3\envs\opencv-env\Lib\site-packages (from ultralytics) (3.11.1)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.7.0 in .\anaconda3\envs\opencv-env\Lib\site-packages (from ultralytics) (5.0.0)
# Requirement already satisfied: pillow>=7.1.2 in .\anaconda3\envs\opencv-env\Lib\site-packages (from ultralytics) (12.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in .\anaconda3\envs\opencv-env\Lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in .\anaconda3\envs\opencv-env\Lib\site-packages (from ultralytics) (2.34.2)
# Requirement already satisfied: torch>=1.8.0 in .\anaconda3\envs\opencv-env\Lib\site-packages (from ultralytics) (2.13.0)
# Requirement already satisfied: torchvision>=0.9.0 in .\anaconda3\envs\opencv-env\Lib\site-packages (from ultralytics) (0.28.0)
# Requirement already satisfied: psutil>=5.8.0 in .\anaconda3\envs\opencv-env\Lib\site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in .\anaconda3\envs\opencv-env\Lib\site-packages (from ultralytics) (1.43.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in .\anaconda3\envs\opencv-env\Lib\site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.1.6 in .\anaconda3\envs\opencv-env\Lib\site-packages (from ultralytics) (2.1.6)
# Requirement already satisfied: ultralytics-platform>=0.1.3 in .\anaconda3\envs\opencv-env\Lib\site-packages (from ultralytics) (0.1.7)
# Requirement already satisfied: contourpy>=1.0.1 in .\anaconda3\envs\opencv-env\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\anaconda3\envs\opencv-env\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in .\anaconda3\envs\opencv-env\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\anaconda3\envs\opencv-env\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in .\anaconda3\envs\opencv-env\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=3 in .\anaconda3\envs\opencv-env\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\anaconda3\envs\opencv-env\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.43.2 in .\anaconda3\envs\opencv-env\Lib\site-packages (from polars>=0.20.0->ultralytics) (1.43.2)
# Requirement already satisfied: six>=1.5 in .\anaconda3\envs\opencv-env\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\anaconda3\envs\opencv-env\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in .\anaconda3\envs\opencv-env\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in .\anaconda3\envs\opencv-env\Lib\site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\anaconda3\envs\opencv-env\Lib\site-packages (from requests>=2.23.0->ultralytics) (2026.7.22)
# Requirement already satisfied: typing-extensions>=4.10.0 in .\anaconda3\envs\opencv-env\Lib\site-packages (from torch>=1.8.0->ultralytics) (4.16.0)
# Requirement already satisfied: setuptools>=77.0.3 in .\anaconda3\envs\opencv-env\Lib\site-packages (from torch>=1.8.0->ultralytics) (83.0.0)
# Requirement already satisfied: sympy>=1.13.3 in .\anaconda3\envs\opencv-env\Lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in .\anaconda3\envs\opencv-env\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in .\anaconda3\envs\opencv-env\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in .\anaconda3\envs\opencv-env\Lib\site-packages (from torch>=1.8.0->ultralytics) (2026.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\anaconda3\envs\opencv-env\Lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: httpx<1,>=0.28 in .\anaconda3\envs\opencv-env\Lib\site-packages (from ultralytics-platform>=0.1.3->ultralytics) (0.28.1)
# Requirement already satisfied: anyio in .\anaconda3\envs\opencv-env\Lib\site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.3->ultralytics) (4.14.2)
# Requirement already satisfied: httpcore==1.* in .\anaconda3\envs\opencv-env\Lib\site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.3->ultralytics) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\anaconda3\envs\opencv-env\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.28->ultralytics-platform>=0.1.3->ultralytics) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\anaconda3\envs\opencv-env\Lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
# Load faster YOLO model
model = YOLO("yolov8n.pt")

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

model = YOLO("yolov8n.pt")

cap = cv2.VideoCapture(0)

ret, frame = cap.read()

if ret:
    results = model(frame, imgsz=320, conf=0.5, verbose=False)

    annotated = results[0].plot()
    annotated = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)

    plt.figure(figsize=(10, 6))
    plt.imshow(annotated)
    plt.title("Real-Time Object Detection")
    plt.axis("off")
    plt.show()

cap.release()
